# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing datasets
df = pd.read_csv('retail_sales_dataset.csv')

# %%
#taking a peek at the first few rows
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
#viewing the last five rows
df.tail()
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %%
# Summary of the data
df.describe
# Out:
# <bound method NDFrame.describe of      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
#information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
#identify missing values
df.isnull()
# Out:
#      Transaction ID   Date  Customer ID  Gender    Age  Product Category  \
# 0             False  False        False   False  False             False
# 1             False  False        False   False  False             False
# 2             False  False        False   False  False             False
# 3             False  False        False   False  False             False
# 4             False  False        False   False  False             False
# ..              ...    ...          ...     ...    ...               ...
# 995           False  False        False   False  False             False
# 996           False  False        False   False  False             False
# 997           False  False        False   False  False             False
# 998           False  False        False   False  False             False
# 999           False  False        False   False  False             False
#
#      Quantity  Price per Unit  Total Amount
# 0       False           False         False
# ...

# %%
#count number of missing values in each column
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
#converting the columns to lowercase and replacing space with (_)
df.columns=df.columns.str.lower().str.replace(' ','_')

# %%
#viewing the dataset
df
# Out:
#      transaction_id        date customer_id  gender  age product_category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      quantity  price_per_unit  total_amount
# ...

# %%
#converting gender data type to category
df['gender']= df['gender'].astype('category')

# %%
#converting product_category data type to category
df['product_category']= df['product_category'].astype('category')

# %%
# Convert the 'date' column to a datetime-like index
df['date']= pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# transaction_id               int64
# date                datetime64[ns]
# customer_id                 object
# gender                    category
# age                          int64
# product_category          category
# quantity                     int64
# price_per_unit               int64
# total_amount                 int64
# dtype: object

# %%
#descriptive statistics
df.describe()
# Out:
#        transaction_id                           date         age     quantity  \
# count     1000.000000                           1000  1000.00000  1000.000000
# mean       500.500000  2023-07-03 00:25:55.200000256    41.39200     2.514000
# min          1.000000            2023-01-01 00:00:00    18.00000     1.000000
# 25%        250.750000            2023-04-08 00:00:00    29.00000     1.000000
# 50%        500.500000            2023-06-29 12:00:00    42.00000     3.000000
# 75%        750.250000            2023-10-04 00:00:00    53.00000     4.000000
# max       1000.000000            2024-01-01 00:00:00    64.00000     4.000000
# std        288.819436                            NaN    13.68143     1.132734
#
#        price_per_unit  total_amount
# count     1000.000000   1000.000000
# mean       179.890000    456.000000
# min         25.000000     25.000000
# 25%         30.000000     60.000000
# 50%         50.000000    135.000000
# 75%        300.000000    900.000000
# ...

# %%
#gender distribution analysis 
df['gender'].value_counts()
# Out:
# gender
# Female    510
# Male      490
# Name: count, dtype: int64

# %%
#pie chart 
df['gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title ('Gender Distribution')
plt.ylabel('Percentage Distribution')
plt.show()

# %%
# product category distribution frequency
df['product_category'].value_counts()
# Out:
# product_category
# Clothing       351
# Electronics    342
# Beauty         307
# Name: count, dtype: int64

# %%
# Bar chart
df ['product_category'] .value_counts() .plot(kind='bar', rot=45)
plt.xlabel ('Product Category')
plt.ylabel ('Count')
plt.title ('Product Category Distribution')
plt.show()

# %%
# grouping age data, defining the age bin
age_bins = [18, 30, 40, 50, 60, 64]
# defining labels for the age group
age_labels= [ '18-29', '30-39', '40-49', '50-59', '60-64']
# creating a new column with the age groups
df['age_group'] = pd.cut(df['age'], bins= age_bins, labels=age_labels, right= False)

# %%
#age descriptive statistics
df['age'].describe()
# Out:
# count    1000.00000
# mean       41.39200
# std        13.68143
# min        18.00000
# 25%        29.00000
# 50%        42.00000
# 75%        53.00000
# max        64.00000
# Name: age, dtype: float64

# %%
df['age_group']
# Out:
# 0      30-39
# 1      18-29
# 2      50-59
# 3      30-39
# 4      30-39
#        ...
# 995    60-64
# 996    50-59
# 997    18-29
# 998    30-39
# 999    40-49
# Name: age_group, Length: 1000, dtype: category
# Categories (5, object): ['18-29' < '30-39' < '40-49' < '50-59' < '60-64']

# %%
# plotting the age group distribution frequency
age_group_counts = df['age_group'].value_counts().sort_index()
plt.bar(age_group_counts.index, age_group_counts)
# adding labels and titles
plt.xlabel('Age Group')
plt.ylabel('Frequency')
plt.title('Bar Chart of Age Groups')
plt.show()

# %%
#average monthly sales
# extracting month from the 'date' column
df['month'] = df['date'].dt.month

# calculating average monthly sales
monthly_avg_sales = df.groupby('month')['total_amount'].mean()

# ploting the average monthly sales
monthly_avg_sales.plot(kind='line', marker='o', title='Average Monthly Sales', xlabel='Month', ylabel='Average Sales')
plt.show()

# %%
# Resampling the data to calculate average monthly sales
df.set_index('date', inplace=True)
avg_monthly_sales = df['total_amount'].resample('M').mean()

# Plot the average monthly sales
plt.figure(figsize=(10, 6))
avg_monthly_sales.plot(kind='line', marker='o', title='Average Monthly Sales', xlabel='Month', ylabel='Average Sales', grid=True)
plt.show()

# %%
# resampling to calculate the average quarterly sales
avg_quarterly_sales = df['total_amount'].resample('Q').mean()

# Plot the average monthly sales
plt.figure(figsize=(10, 6))
avg_quarterly_sales.plot(kind='line', marker='o', title='Quarter Average Sales', xlabel='Quarter', ylabel='Average Sales', grid=True)
plt.show()

# %%
# Customer and Product analysis, gender vs product category
pd.crosstab(df['gender'], df['product_category'])
# Out:
# product_category  Beauty  Clothing  Electronics
# gender
# Female               166       174          170
# Male                 141       177          172

# %%
#gender vs quantity
pd.crosstab(df['gender'], df['quantity'])
# Out:
# quantity    1    2    3    4
# gender
# Female    125  120  127  138
# Male      128  123  114  125

# %%
# plotting age and total_amount
sns.scatterplot(data= df, x='age_group', y='total_amount')
plt.show()
# correlation
df['age'].corr(df['total_amount'])
# Out:
# -0.060568023883045684

# %%
# price_per_unit vs total_amount
sns.scatterplot(df, x='price_per_unit', y='total_amount')
plt.show()
# correlation
df['price_per_unit'].corr(df['total_amount'])
# Out:
# 0.8519248403554025

# %%
# plotting gender vs total amount
sns.boxplot(data=df, x='gender', y='total_amount')
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# product category vs total amount
sns.boxplot(data= df, x='product_category', y='total_amount')
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# price_per_unit vs total_amount
plt.figure(figsize=(10, 6))
plt.scatter(df['price_per_unit'], df['total_amount'], alpha=0.5)
plt.title('Price per Unit vs Total Amount')
plt.xlabel('Price per Unit')
plt.ylabel('Total Amount')
plt.grid(True)

# %%
# Creating a bar plot 
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='product_category', y='total_amount', hue='gender', palette='pastel')
plt.title('Total Amount Across Product Categories with Gender')
plt.xlabel('Product Category')
plt.ylabel('Total Amount')
plt.legend(title='Gender',bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
df.groupby(['price_per_unit','gender'], observed=False)['total_amount'].describe()
# Out:
#                        count         mean         std    min     25%     50%  \
# price_per_unit gender
# 25             Female  115.0    63.043478   28.165361   25.0    50.0    50.0
#                Male     95.0    61.052632   28.179655   25.0    37.5    50.0
# 30             Female   92.0    74.347826   33.718432   30.0    30.0    75.0
#                Male     91.0    71.538462   34.283883   30.0    30.0    60.0
# 50             Female   98.0   131.122449   58.992969   50.0   100.0   150.0
#                Male    113.0   122.566372   57.473266   50.0    50.0   100.0
# 300            Female  106.0   786.792453  340.049148  300.0   600.0   900.0
#                Male     91.0   791.208791  333.216097  300.0   600.0   900.0
# 500            Female   99.0  1237.373737  554.864547  500.0  1000.0  1000.0
#                Male    100.0  1250.000000  570.751764  500.0   500.0  1500.0
#
#                           75%     max
# price_per_unit gender
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='price_per_unit', y='total_amount', hue='gender', palette='Set1')
plt.title('Total Amount vs Price per Unit with Gender')
plt.xlabel('Price per Unit')
plt.ylabel('Total Amount')
plt.legend(title='Gender')
plt.show()
